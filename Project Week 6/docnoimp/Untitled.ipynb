# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
data=pd.read_csv("german_credit_data.csv")

# %% [markdown]
# Age (numeric)
# Sex (text: male, female)
# Job (numeric: 0 - unskilled and non-resident, 1 - unskilled and resident, 2 - skilled, 3 - highly skilled)
# Housing (text: own, rent, or free)
# Saving accounts (text - little, moderate, quite rich, rich)
# Checking account (numeric, in DM - Deutsch Mark)
# Credit amount (numeric, in DM)
# Duration (numeric, in month)
# Purpose (text: car, furniture/equipment, radio/TV, domestic appliances, repairs, education, business, vacation/others)

# %%
Questions:
Wich age is the most commun for have a credit consumer

# %%
data=data.drop('Unnamed: 0', axis=1)
pd.pivot_table(data, columns='Housing')
# Out:
# Housing               free          own         rent
# Age              43.814815    35.593268    30.368715
# Credit amount  4906.212963  3060.939691  3122.553073
# Duration         27.453704    20.328191    19.240223
# Job               2.157407     1.879383     1.849162

# %%
data=data.sort_values(by="Age")

# %%
data
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 391   19  female    1    rent            rich         moderate            983
# 633   19  female    2    rent          little              NaN           1980
# 513   20    male    2    rent          little         moderate            585
# 155   20  female    2    rent          little           little           1282
# 410   20  female    2     own          little         moderate           1967
# 865   20  female    2    rent      quite rich              NaN           2221
# 420   20  female    2    rent            rich              NaN           3186
# 167   20  female    2     own            rich         moderate           1577
# 296   20  female    2    rent             NaN              NaN           4675
# 905   20    male    3    rent          little           little           1107
# 593   20  female    1    rent          little         moderate           2718
# 585   20  female    2    rent          little           little           2039
# 428   20    male    2     own          little              NaN           1313
# 188   20    male    2     own        moderate           little            674
# 495   20    male    2     own             NaN           little           2996
# 93    20    male    2    rent             NaN             rich           3617
# 386   21  female    2    rent             NaN              NaN           1126
# 836   21  female    2     own             NaN              NaN            886
# 724   21  female    2    rent          little              NaN           2570
# 731   21    male    1    rent          little           little           1987
# 363   21    male    2    rent          little              NaN           1766
# 618   21  female    2    rent        moderate         moderate           3441
# 425   21    male    2    rent          little         moderate           2779
# 587   21    male    1     own          little           little           1289
# 208   21    male    1     own          little           little           6568
# 194   21    male    2    rent        moderate         moderate           3031
# 134   21  female    2     own        moderate              NaN          10144
# 637   21    male    2     own          little              NaN          15653
# 203   21    male    2    rent          little           little            902
# 926   21  female    2    rent          little           little           1049
# ..   ...     ...  ...     ...             ...              ...            ...
# 373   63    male    3    free             NaN              NaN          13756
# 715   63    male    2     own             NaN              NaN           7596
# 678   64    male    1    rent          little           little           2384
# 629   64    male    1     own             NaN              NaN           3832
# 976   64  female    2     own          little         moderate            753
# 987   64  female    2     own        moderate              NaN           1409
# 219   64  female    2     own          little              NaN           1364
# 807   65    male    2     own             NaN              NaN            930
# 624   65    male    2    free          little           little           2600
# 883   65  female    0     own          little              NaN           1098
# 179   65    male    2     own          little           little            571
# 438   65    male    0     own          little           little           3394
# 774   66    male    0    free      quite rich             rich           1480
# 75    66    male    3    free          little           little           1526
# 723   66  female    1     own      quite rich         moderate            790
# 213   66    male    3     own          little             rich           1908
# 137   66    male    1     own      quite rich         moderate            766
# 779   67  female    2     own          little         moderate           3872
# 0     67    male    2     own             NaN           little           1169
# 554   67  female    3     own          little         moderate           1199
# 187   68    male    0    free          little         moderate           1175
# 846   68    male    2    rent             NaN              NaN           6761
# 917   68    male    3     own          little           little          14896
# 163   70    male    3    free          little         moderate           7308
# 756   74    male    0     own          little             rich           1299
# 606   74    male    3     own          little              NaN           4526
# 186   74  female    3    free          little         moderate           5129
# 430   74    male    1     own          little              NaN           3448
# 330   75    male    3    free          little           little           6615
# 536   75  female    3     own             NaN           little           1374
#
#      Duration              Purpose
# 391        12  furniture/equipment
# 633         9  furniture/equipment
# 513        12             radio/TV
# 155        12  furniture/equipment
# 410        24             radio/TV
# 865        15  furniture/equipment
# 420        15                  car
# 167        11  furniture/equipment
# 296        12                  car
# 905        12             radio/TV
# 593        24                  car
# 585        18  furniture/equipment
# 428         9  furniture/equipment
# 188        12             radio/TV
# 495        24  furniture/equipment
# 93         24  furniture/equipment
# 386        18             radio/TV
# 836        12             radio/TV
# 724        27                  car
# 731        24             radio/TV
# 363         6  furniture/equipment
# 618        30  furniture/equipment
# 425        18                  car
# 587        12  furniture/equipment
# 208        24             business
# 194        45             radio/TV
# 134        60             radio/TV
# 637        60             radio/TV
# 203        12            education
# 926        18  furniture/equipment
# ..        ...                  ...
# 373        60                  car
# 715        30                  car
# 678        24             radio/TV
# 629         9            education
# 976         6             radio/TV
# 987        13             radio/TV
# 219        10                  car
# 807        12             radio/TV
# 624        18             radio/TV
# 883        18             radio/TV
# 179        21                  car
# 438        42              repairs
# 774        12                  car
# 75         12                  car
# 723         9             radio/TV
# 213        30             business
# 137        12             radio/TV
# 779        18              repairs
# 0           6             radio/TV
# 554         9            education
# 187        16                  car
# 846        18                  car
# 917         6                  car
# 163        10                  car
# 756         6                  car
# 606        24             business
# 186         9                  car
# 430         5             business
# 330        24                  car
# 536         6                  car
#
# [1000 rows x 9 columns]
